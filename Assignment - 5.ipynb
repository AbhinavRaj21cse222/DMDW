# %% [markdown]
# ## Normalization (Min-max, z- score, Decimal Scaling) techniques.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import math
import statistics as st
% matplotlib in line
# Out:
# UsageError: Line magic function `%` not found.

# %%
df = pd.read_csv('Toyota.csv')
df.head(10)
# Out:
#    Unnamed: 0  Price   Age     KM FuelType    HP  MetColor  Automatic    CC  \
# 0           0  13500  23.0  46986   Diesel    90       1.0          0  2000
# 1           1  13750  23.0  72937   Diesel    90       1.0          0  2000
# 2           2  13950  24.0  41711   Diesel    90       NaN          0  2000
# 3           3  14950  26.0  48000   Diesel    90       0.0          0  2000
# 4           4  13750  30.0  38500   Diesel    90       0.0          0  2000
# 5           5  12950  32.0  61000   Diesel    90       0.0          0  2000
# 6           6  16900  27.0     ??   Diesel  ????       NaN          0  2000
# 7           7  18600  30.0  75889      NaN    90       1.0          0  2000
# 8           8  21500  27.0  19700   Petrol   192       0.0          0  1800
# 9           9  12950  23.0  71138   Diesel  ????       NaN          0  1900
#
#    Doors  Weight
# 0  three    1165
# 1      3    1165
# 2      3    1165
# 3      3    1165
# 4      3    1170
# 5      3    1170
# ...

# %%
df.shape
# Out:
# (1436, 11)

# %%
df.head()
# Out:
#    Unnamed: 0  Price   Age     KM FuelType  HP  MetColor  Automatic    CC  \
# 0           0  13500  23.0  46986   Diesel  90       1.0          0  2000
# 1           1  13750  23.0  72937   Diesel  90       1.0          0  2000
# 2           2  13950  24.0  41711   Diesel  90       NaN          0  2000
# 3           3  14950  26.0  48000   Diesel  90       0.0          0  2000
# 4           4  13750  30.0  38500   Diesel  90       0.0          0  2000
#
#    Doors  Weight
# 0  three    1165
# 1      3    1165
# 2      3    1165
# 3      3    1165
# 4      3    1170

# %%
df.sample(10)
# Out:
#       Unnamed: 0  Price   Age      KM FuelType   HP  MetColor  Automatic  \
# 88            88  15950  19.0   51884   Petrol   97       1.0          0
# 76            76  18750  31.0   25266   Petrol  110       1.0          0
# 752          752   8450  65.0   80439   Petrol  110       1.0          0
# 359          359  14350  41.0   24475   Petrol  110       NaN          0
# 790          790   9500  66.0   74963   Petrol  107       0.0          1
# 12            12  19600  25.0   32189   Petrol  192       0.0          0
# 826          826   6950  58.0   69022   Petrol   86       1.0          0
# 398          398  10500  55.0      ??   Petrol  110       1.0          0
# 1268        1268   8950  69.0   75000   Petrol   86       1.0          0
# 1141        1141   7950  73.0  103121   Petrol   86       1.0          0
#
#         CC Doors  Weight
# 88    1400     3    1100
# 76    1600     5    1130
# 752   1600     4    1035
# 359   1600     5    1030
# 790   1600     3    1085
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# Price           int64
# Age           float64
# KM             object
# FuelType       object
# HP             object
# MetColor      float64
# Automatic       int64
# CC              int64
# Doors          object
# Weight          int64
# dtype: object

# %%
df.describe()
# Out:
#         Unnamed: 0         Price          Age     MetColor    Automatic  \
# count  1436.000000   1436.000000  1336.000000  1286.000000  1436.000000
# mean    717.500000  10730.824513    55.672156     0.674961     0.055710
# std     414.681806   3626.964585    18.589804     0.468572     0.229441
# min       0.000000   4350.000000     1.000000     0.000000     0.000000
# 25%     358.750000   8450.000000    43.000000     0.000000     0.000000
# 50%     717.500000   9900.000000    60.000000     1.000000     0.000000
# 75%    1076.250000  11950.000000    70.000000     1.000000     0.000000
# max    1435.000000  32500.000000    80.000000     1.000000     1.000000
#
#                 CC      Weight
# count  1436.000000  1436.00000
# mean   1566.827994  1072.45961
# std     187.182436    52.64112
# min    1300.000000  1000.00000
# 25%    1400.000000  1040.00000
# 50%    1600.000000  1070.00000
# 75%    1600.000000  1085.00000
# max    2000.000000  1615.00000

# %%
df.describe(include='all')
# Out:
#          Unnamed: 0         Price          Age    KM FuelType    HP  \
# count   1436.000000   1436.000000  1336.000000  1436     1336  1436
# unique          NaN           NaN          NaN  1256        3    13
# top             NaN           NaN          NaN    ??   Petrol   110
# freq            NaN           NaN          NaN    15     1177   833
# mean     717.500000  10730.824513    55.672156   NaN      NaN   NaN
# std      414.681806   3626.964585    18.589804   NaN      NaN   NaN
# min        0.000000   4350.000000     1.000000   NaN      NaN   NaN
# 25%      358.750000   8450.000000    43.000000   NaN      NaN   NaN
# 50%      717.500000   9900.000000    60.000000   NaN      NaN   NaN
# 75%     1076.250000  11950.000000    70.000000   NaN      NaN   NaN
# max     1435.000000  32500.000000    80.000000   NaN      NaN   NaN
#
#            MetColor    Automatic           CC Doors      Weight
# count   1286.000000  1436.000000  1436.000000  1436  1436.00000
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      0
# Price           0
# Age           100
# KM              0
# FuelType      100
# HP              0
# MetColor      150
# Automatic       0
# CC              0
# Doors           0
# Weight          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df = df.select_dtypes(exclude=['object'])

# %%
df_min_max = df.copy()

# %%
for column in df_min_max.columns:
    df_min_max[column] = (df_min_max[column] - df_min_max[column].min()) / (df_min_max[column].max() - df_min_max[column].min())
    print(df_min_max)
# Out:
#       Unnamed: 0  Price   Age  MetColor  Automatic    CC  Weight
# 0       0.000000  13500  23.0       1.0          0  2000    1165
# 1       0.000697  13750  23.0       1.0          0  2000    1165
# 2       0.001394  13950  24.0       NaN          0  2000    1165
# 3       0.002091  14950  26.0       0.0          0  2000    1165
# 4       0.002787  13750  30.0       0.0          0  2000    1170
# ...          ...    ...   ...       ...        ...   ...     ...
# 1431    0.997213   7500   NaN       1.0          0  1300    1025
# 1432    0.997909  10845  72.0       0.0          0  1300    1015
# 1433    0.998606   8500   NaN       0.0          0  1300    1015
# 1434    0.999303   7250  70.0       1.0          0  1300    1015
# 1435    1.000000   6950  76.0       0.0          0  1600    1114
#
# [1436 rows x 7 columns]
#       Unnamed: 0     Price   Age  MetColor  Automatic    CC  Weight
# 0       0.000000  0.325044  23.0       1.0          0  2000    1165
# ...

# %%
df_z_score = df.copy()

# z-score normalization techniques
for column in df_z_score.columns:
    df_z_score[column] = (df_z_score[column] - df_z_score[column].mean()) / df_z_score[column].std()

# %%
display(df_z_score)
# Out:
#       Unnamed: 0     Price       Age  MetColor  Automatic        CC    Weight
# 0      -1.730242  0.763497 -1.757531  0.693680  -0.242808  2.314170  1.757949
# 1      -1.727831  0.832425 -1.757531  0.693680  -0.242808  2.314170  1.757949
# 2      -1.725419  0.887567 -1.703738       NaN  -0.242808  2.314170  1.757949
# 3      -1.723008  1.163280 -1.596152 -1.440465  -0.242808  2.314170  1.757949
# 4      -1.720596  0.832425 -1.380980 -1.440465  -0.242808  2.314170  1.852931
# ...          ...       ...       ...       ...        ...       ...       ...
# 1431    1.720596 -0.890779       NaN  0.693680  -0.242808 -1.425497 -0.901569
# 1432    1.723008  0.031480  0.878323 -1.440465  -0.242808 -1.425497 -1.091535
# 1433    1.725419 -0.615067       NaN -1.440465  -0.242808 -1.425497 -1.091535
# 1434    1.727831 -0.959707  0.770737  0.693680  -0.242808 -1.425497 -1.091535
# 1435    1.730242 -1.042421  1.093494 -1.440465  -0.242808  0.177218  0.789124
#
# [1436 rows x 7 columns]
