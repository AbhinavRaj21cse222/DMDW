# %% [markdown]
# ## Correlation Co-efficient realation and Co varience analysis

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import math
import statistics as st
% matplotlib in line
# Out:
# UsageError: Line magic function `%` not found.

# %%
std=pd.read_csv('student-mat.csv')
std.head(10)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1   at_home     other
# 2     GP   F   15       U     LE3       T     1     1   at_home     other
# 3     GP   F   15       U     GT3       T     4     2    health  services
# 4     GP   F   16       U     GT3       T     3     3     other     other
# 5     GP   M   16       U     LE3       T     4     3  services     other
# 6     GP   M   16       U     LE3       T     2     2     other     other
# 7     GP   F   17       U     GT3       A     4     4     other   teacher
# 8     GP   M   15       U     LE3       A     3     2  services     other
# 9     GP   M   15       U     GT3       T     3     4     other     other
#
#    ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0  ...      4        3      4     1     1      3        6   5   6   6
# ...

# %%
std.tail(20)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 375     MS   F   18       R     GT3       T     1     1     other     other
# 376     MS   F   20       U     GT3       T     4     2    health     other
# 377     MS   F   18       R     LE3       T     4     4   teacher  services
# 378     MS   F   18       U     GT3       T     3     3     other     other
# 379     MS   F   17       R     GT3       T     3     1   at_home     other
# 380     MS   M   18       U     GT3       T     4     4   teacher   teacher
# 381     MS   M   18       R     GT3       T     2     1     other     other
# 382     MS   M   17       U     GT3       T     2     3     other  services
# 383     MS   M   19       R     GT3       T     1     1     other  services
# 384     MS   M   18       R     GT3       T     4     2     other     other
# 385     MS   F   18       R     GT3       T     2     2   at_home     other
# ...

# %%
std.corr()
# Out:
# C:\Users\abhin\AppData\Local\Temp\ipykernel_16716\1768128686.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   std.corr()
#                  age      Medu      Fedu  traveltime  studytime  failures  \
# age         1.000000 -0.163658 -0.163438    0.070641  -0.004140  0.243665
# Medu       -0.163658  1.000000  0.623455   -0.171639   0.064944 -0.236680
# Fedu       -0.163438  0.623455  1.000000   -0.158194  -0.009175 -0.250408
# traveltime  0.070641 -0.171639 -0.158194    1.000000  -0.100909  0.092239
# studytime  -0.004140  0.064944 -0.009175   -0.100909   1.000000 -0.173563
# failures    0.243665 -0.236680 -0.250408    0.092239  -0.173563  1.000000
# famrel      0.053940 -0.003914 -0.001370   -0.016808   0.039731 -0.044337
# freetime    0.016434  0.030891 -0.012846   -0.017025  -0.143198  0.091987
# ...

# %%
columns_of_interest2 = [ 'studytime','freetime']

# %%
subset_data = std[columns_of_interest2]

# %%
correlation_matrix = subset_data.corr()

# %%
covariance_matrix = subset_data.cov()

# %%
print("Correlation Matrix:")
print(correlation_matrix)
# Out:
# Correlation Matrix:
#            studytime  freetime
# studytime   1.000000 -0.143198
# freetime   -0.143198  1.000000

# %%
sns.heatmap(correlation_matrix,cmap ="YlGnBu")
plt.show()

# %%
print("\nCovariance Matrix:")
print(covariance_matrix)
# Out:
# Covariance Matrix:
#            studytime  freetime
# studytime   0.704324 -0.120041
# freetime   -0.120041  0.997725

# %%
sns.heatmap(covariance_matrix,cmap ="coolwarm")
plt.show()

# %%
columns_of_interest5 = [ 'studytime','freetime','age','Fedu','failures']

# %%
subset_data = std[columns_of_interest5]

# %%
correlation_matrix = subset_data.corr()

# %%
covariance_matrix = subset_data.cov()

# %%
print("Correlation Matrix:")
print(correlation_matrix)
# Out:
# Correlation Matrix:
#            studytime  freetime       age      Fedu  failures
# studytime   1.000000 -0.143198 -0.004140 -0.009175 -0.173563
# freetime   -0.143198  1.000000  0.016434 -0.012846  0.091987
# age        -0.004140  0.016434  1.000000 -0.163438  0.243665
# Fedu       -0.009175 -0.012846 -0.163438  1.000000 -0.250408
# failures   -0.173563  0.091987  0.243665 -0.250408  1.000000

# %%
sns.heatmap(covariance_matrix,cmap ="YlGnBu")
plt.show()

# %%
column_of_intrested=['age','Medu','Fedu','traveltime','studytime','failures','famrel','freetime','goout','Dalc','Walc','health','absences','G1','G2','G3']

# %%
subset_data = std[column_of_intrested]

# %%
correlation_matrix = subset_data.corr()

# %%
covariance_matrix = subset_data.cov()

# %%
print("Correlation Matrix:")
print(correlation_matrix)
# Out:
# Correlation Matrix:
#                  age      Medu      Fedu  traveltime  studytime  failures  \
# age         1.000000 -0.163658 -0.163438    0.070641  -0.004140  0.243665
# Medu       -0.163658  1.000000  0.623455   -0.171639   0.064944 -0.236680
# Fedu       -0.163438  0.623455  1.000000   -0.158194  -0.009175 -0.250408
# traveltime  0.070641 -0.171639 -0.158194    1.000000  -0.100909  0.092239
# studytime  -0.004140  0.064944 -0.009175   -0.100909   1.000000 -0.173563
# failures    0.243665 -0.236680 -0.250408    0.092239  -0.173563  1.000000
# famrel      0.053940 -0.003914 -0.001370   -0.016808   0.039731 -0.044337
# freetime    0.016434  0.030891 -0.012846   -0.017025  -0.143198  0.091987
# goout       0.126964  0.064094  0.043105    0.028540  -0.063904  0.124561
# Dalc        0.131125  0.019834  0.002386    0.138325  -0.196019  0.136047
# Walc        0.117276 -0.047123 -0.012631    0.134116  -0.253785  0.141962
# ...

# %%
sns.heatmap(covariance_matrix,cmap ="YlGnBu")
plt.show()

# %%
print("covariance_matrix:")
print(covariance_matrix)
# Out:
# covariance_matrix:
#                  age      Medu      Fedu  traveltime  studytime  failures  \
# age         1.628285 -0.228619 -0.226949    0.062873  -0.004434  0.231221
# Medu       -0.228619  1.198445  0.742717   -0.131061   0.059667 -0.192681
# Fedu       -0.226949  0.742717  1.184180   -0.120073  -0.008379 -0.202641
# traveltime  0.062873 -0.131061 -0.120073    0.486513  -0.059070  0.047844
# studytime  -0.004434  0.059667 -0.008379   -0.059070   0.704324 -0.108321
# failures    0.231221 -0.192681 -0.202641    0.047844  -0.108321  0.553017
# famrel      0.061717 -0.003842 -0.001337   -0.010512   0.029898 -0.029564
# freetime    0.020947  0.033779 -0.013963   -0.011861  -0.120041  0.068329
# goout       0.180364  0.078115  0.052220    0.022162  -0.059706  0.103123
# Dalc        0.149039  0.019341  0.002313    0.085941  -0.146533  0.090118
# Walc        0.192733 -0.066440 -0.017702    0.120478  -0.274304  0.135964
# ...

# %%
sns.heatmap(correlation_matrix,cmap ="YlGnBu")
plt.show()
